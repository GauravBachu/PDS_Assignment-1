# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv("../data_raw/StudentsPerformance.csv")

# %% [markdown]
# ### Data Cleaning

# %%
data_set.dropna(inplace=True)
data_set.to_csv("../data_clean/StudentPerformance_clean.csv", index=False)
data_set
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
summary = data_set.describe()
print(summary)
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### Visualization 1: Gender Distribution

# %%
colors = {'male': 'skyblue', 'female': 'salmon'}
plt.figure(figsize=(8, 6))
sns.countplot(data=data_set, x='gender', palette=colors, hue='gender', legend=False)
plt.title('Distribution of Students by Gender')  
plt.xlabel('Gender')
plt.ylabel('Count')
plt.savefig("../results/gender_distribution.png") 
plt.show()

# %% [markdown]
# ### Visualization 2: Parental Educational Level by Gender

# %%
colors = {'male': 'skyblue', 'female': 'salmon'}
plt.figure(figsize=(10, 6))
sns.countplot(data=data_set, x='parental level of education', palette=colors, hue='gender')
plt.title('Parental Education Level by Gender')
plt.xlabel('Parental Education Level')
plt.ylabel('Count')
plt.xticks(rotation=60, ha='right')
plt.legend(title='Gender')
plt.savefig("../results/parents_education_levels.png")

plt.show()

# %% [markdown]
# ### Visualization 3: Test Preparation Course Effect

# %% [markdown]
# #### For Math Score

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_set, x='test preparation course', y='math score', color = 'skyblue')
plt.title('Math Scores by Test Preparation Course')
plt.xlabel('Test Preparation Course')
plt.ylabel('Math Score')
plt.savefig("../results/box_plot_math_scores.png")
plt.show()

# %% [markdown]
# #### For Reading Score

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_set, x='test preparation course', y='reading score', color = 'lightpink')
plt.title('Math Scores by Test Preparation Course')
plt.xlabel('Test Preparation Course')
plt.ylabel('Math Score')
plt.savefig("../results/boxplot_reading_scores.png")
plt.show()

# %% [markdown]
# #### For Writing Score

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_set, x='test preparation course', y='writing score', color = 'lightgreen')
plt.title('Math Scores by Test Preparation Course')
plt.xlabel('Test Preparation Course')
plt.ylabel('Math Score')
plt.savefig("../results/box_plot_writing_scores.png")
plt.show()

# %% [markdown]
# ### Visualization 4: Lunch Arrangement Effect

# %% [markdown]
# #### For Math Score

# %%
colors = ['skyblue', 'salmon']
plt.figure(figsize=(8, 6))
sns.violinplot(data=data_set, x='lunch', y='math score', hue='gender',palette=colors, split=True)
plt.title('Math Scores by Lunch Type and Gender')
plt.xlabel('Lunch Type')
plt.ylabel('Math Score')
plt.legend(title='Gender')
plt.savefig("../results/violinplot_mathscores_lunch.png")
plt.show()

# %% [markdown]
# #### For Reading Score

# %%
colors = ['yellow', 'orange']
plt.figure(figsize=(8, 6))
sns.violinplot(data=data_set, x='lunch', y='reading score', hue='gender', palette=colors, split=True)
plt.title('Reading Scores by Lunch Type and Gender')
plt.xlabel('Lunch Type')
plt.ylabel('Reading Score')
plt.legend(title='Gender')
plt.savefig("../results/violinplot_readingscores_lunch.png")
plt.show()

# %% [markdown]
# #### For Writing Score

# %%
colors = ['lightgrey', 'lightcoral']
plt.figure(figsize=(8, 6))
sns.violinplot(data=data_set, x='lunch', y='writing score', hue='gender', palette=colors, split=True)
plt.title('Math Scores by Lunch Type and Gender')
plt.xlabel('Lunch Type')
plt.ylabel('Writing Score')
plt.legend(title='Gender')
plt.savefig("../results/violinplot_writingscores_lunch.png")
plt.show()

# %% [markdown]
# ### Visualization 5: Correlation HeatMap Among Math, Reading, and Writing Scores

# %%
corr_matrix = data_set[['math score', 'reading score', 'writing score']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='magma', fmt=".3f")
plt.title('Correlation Heatmap')
plt.savefig("../results/math_reading_writing.png")
plt.show()
